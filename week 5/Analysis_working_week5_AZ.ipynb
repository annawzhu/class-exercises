# %%
# # Read in data
# import pandas as pd

# df = pd.read_csv(filepath_or_buffer='./communities.data', sep=',', header=None, na_values='?', keep_default_na=True)
# column_names = ['state', 'county', 'community', 'communityname', 'fold', 'population', 'householdsize', 'racepctblack', 'racePctWhite', 'racePctAsian', 'racePctHisp', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'numbUrban', 'pctUrban', 'medIncome', 'pctWWage', 'pctWFarmSelf', 'pctWInvInc', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'medFamInc', 'perCapInc', 'whitePerCap', 'blackPerCap', 'indianPerCap', 'AsianPerCap', 'OtherPerCap', 'HispPerCap', 'NumUnderPov', 'PctPopUnderPov', 'PctLess9thGrade', 'PctNotHSGrad', 'PctBSorMore', 'PctUnemployed', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'PctOccupManu', 'PctOccupMgmtProf', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PersPerFam', 'PctFam2Par', 'PctKids2Par', 'PctYoungKids2Par', 'PctTeen2Par', 'PctWorkMomYoungKids', 'PctWorkMom', 'NumIlleg', 'PctIlleg', 'NumImmig', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctRecentImmig', 'PctRecImmig5', 'PctRecImmig8', 'PctRecImmig10', 'PctSpeakEnglOnly', 'PctNotSpeakEnglWell', 'PctLargHouseFam', 'PctLargHouseOccup', 'PersPerOccupHous', 'PersPerOwnOccHous', 'PersPerRentOccHous', 'PctPersOwnOccup', 'PctPersDenseHous', 'PctHousLess3BR', 'MedNumBR', 'HousVacant', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctHousNoPhone', 'PctWOFullPlumb', 'OwnOccLowQuart', 'OwnOccMedVal', 'OwnOccHiQuart', 'RentLowQ', 'RentMedian', 'RentHighQ', 'MedRent', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'NumInShelters', 'NumStreet', 'PctForeignBorn', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LemasSwornFT', 'LemasSwFTPerPop', 'LemasSwFTFieldOps', 'LemasSwFTFieldPerPop', 'LemasTotalReq', 'LemasTotReqPerPop', 'PolicReqPerOffic', 'PolicPerPop', 'RacialMatchCommPol', 'PctPolicWhite', 'PctPolicBlack', 'PctPolicHisp', 'PctPolicAsian', 'PctPolicMinor', 'OfficAssgnDrugUnits', 'NumKindsDrugsSeiz', 'PolicAveOTWorked', 'LandArea', 'PopDens', 'PctUsePubTrans', 'PolicCars', 'PolicOperBudg', 'LemasPctPolicOnPatr', 'LemasGangUnitDeploy', 'LemasPctOfficDrugUn', 'PolicBudgPerPop', 'ViolentCrimesPerPop']
# df.columns = column_names
# df

import  pandas as pd

# read in the file - which in this case is in csv - comma separated value - format
# we use:
#   sep = ',' to set the separator (noting that comma is actually the default so this is not necessary to include)
#   header = None as the dataset does not have a header row
#   na_values = '?' as this dataset uses the ? to represent missing values
# NOTES:
#   - if a separator other than ',' was used we would use the 'sep=' parameter
#   - if the data were in Excel format we can use pd.read_excel - and there are a number of other methods for different datatypes
# df = pd.read_csv('./communities.data', sep=',', header=None, na_values='?', keep_default_na=True)
# df


# If you are using Google Colaboratory 
# To access files in your Google Drive from Google Colaboratory, you need to authenticate your notebook with Google Drive. Run the following code to authenticate:
from google.colab import drive
drive.mount('/content/drive')

import os

# Set the search parameters
filename = 'communities.data'
search_path = '/content/drive/My Drive/Colab Notebooks/'

# Search for the file
for root, dirs, files in os.walk(search_path):
    if filename in files:
        file_path = os.path.join(root, filename)
        break

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/communities.data', sep=',', header=None, na_values='?', keep_default_na=True) #read the bank dataset from the google drive directory 
df

# df = pd.read_csv(filepath_or_buffer='C:/Users/annaz/Dropbox/Teaching/Teaching Machine Learning/Python_teaching/communities.data', sep=',', header=None, na_values='?', keep_default_na=True)
column_names = ['state', 'county', 'community', 'communityname', 'fold', 'population', 'householdsize', 'racepctblack', 'racePctWhite', 'racePctAsian', 'racePctHisp', 'agePct12t21', 'agePct12t29', 'agePct16t24', 'agePct65up', 'numbUrban', 'pctUrban', 'medIncome', 'pctWWage', 'pctWFarmSelf', 'pctWInvInc', 'pctWSocSec', 'pctWPubAsst', 'pctWRetire', 'medFamInc', 'perCapInc', 'whitePerCap', 'blackPerCap', 'indianPerCap', 'AsianPerCap', 'OtherPerCap', 'HispPerCap', 'NumUnderPov', 'PctPopUnderPov', 'PctLess9thGrade', 'PctNotHSGrad', 'PctBSorMore', 'PctUnemployed', 'PctEmploy', 'PctEmplManu', 'PctEmplProfServ', 'PctOccupManu', 'PctOccupMgmtProf', 'MalePctDivorce', 'MalePctNevMarr', 'FemalePctDiv', 'TotalPctDiv', 'PersPerFam', 'PctFam2Par', 'PctKids2Par', 'PctYoungKids2Par', 'PctTeen2Par', 'PctWorkMomYoungKids', 'PctWorkMom', 'NumIlleg', 'PctIlleg', 'NumImmig', 'PctImmigRecent', 'PctImmigRec5', 'PctImmigRec8', 'PctImmigRec10', 'PctRecentImmig', 'PctRecImmig5', 'PctRecImmig8', 'PctRecImmig10', 'PctSpeakEnglOnly', 'PctNotSpeakEnglWell', 'PctLargHouseFam', 'PctLargHouseOccup', 'PersPerOccupHous', 'PersPerOwnOccHous', 'PersPerRentOccHous', 'PctPersOwnOccup', 'PctPersDenseHous', 'PctHousLess3BR', 'MedNumBR', 'HousVacant', 'PctHousOccup', 'PctHousOwnOcc', 'PctVacantBoarded', 'PctVacMore6Mos', 'MedYrHousBuilt', 'PctHousNoPhone', 'PctWOFullPlumb', 'OwnOccLowQuart', 'OwnOccMedVal', 'OwnOccHiQuart', 'RentLowQ', 'RentMedian', 'RentHighQ', 'MedRent', 'MedRentPctHousInc', 'MedOwnCostPctInc', 'MedOwnCostPctIncNoMtg', 'NumInShelters', 'NumStreet', 'PctForeignBorn', 'PctBornSameState', 'PctSameHouse85', 'PctSameCity85', 'PctSameState85', 'LemasSwornFT', 'LemasSwFTPerPop', 'LemasSwFTFieldOps', 'LemasSwFTFieldPerPop', 'LemasTotalReq', 'LemasTotReqPerPop', 'PolicReqPerOffic', 'PolicPerPop', 'RacialMatchCommPol', 'PctPolicWhite', 'PctPolicBlack', 'PctPolicHisp', 'PctPolicAsian', 'PctPolicMinor', 'OfficAssgnDrugUnits', 'NumKindsDrugsSeiz', 'PolicAveOTWorked', 'LandArea', 'PopDens', 'PctUsePubTrans', 'PolicCars', 'PolicOperBudg', 'LemasPctPolicOnPatr', 'LemasGangUnitDeploy', 'LemasPctOfficDrugUn', 'PolicBudgPerPop', 'ViolentCrimesPerPop']
df.columns = column_names
df
# Out:
#       state  county  community        communityname  fold  population  \
# 0         8     NaN        NaN         Lakewoodcity     1        0.19
# 1        53     NaN        NaN          Tukwilacity     1        0.00
# 2        24     NaN        NaN         Aberdeentown     1        0.00
# 3        34     5.0    81440.0  Willingborotownship     1        0.04
# 4        42    95.0     6096.0    Bethlehemtownship     1        0.01
# ...     ...     ...        ...                  ...   ...         ...
# 1989     12     NaN        NaN    TempleTerracecity    10        0.01
# 1990      6     NaN        NaN          Seasidecity    10        0.05
# 1991      9     9.0    80070.0        Waterburytown    10        0.16
# 1992     25    17.0    72600.0          Walthamcity    10        0.08
# 1993      6     NaN        NaN          Ontariocity    10        0.20
#
#       householdsize  racepctblack  racePctWhite  racePctAsian  ...  LandArea  \
# ...

# %%
# Do Lasso on all 122 variables (same as previously)
y = df['ViolentCrimesPerPop'].copy()
X = df.drop(
    columns=['state', 'county', 'community', 'communityname', 'fold', 'ViolentCrimesPerPop']
)

# %%
# Lasso
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer


grid = {
    'estimator__alpha': np.logspace(-3, -1, 100)
}

# A note on pipelines
# pipeline as essentially a 'wrapper' to make a group of transformers with a final estimator look and behave 
# (programmatically) like a single estimator. 
# So when you call 'fit' on the pipeline, it takes whatever data you pass it, 
# runs it through each of the transformers (SimpleImputer etc) in turn, 
# and then passes it to the 'fit' method of the estimator in the pipeline - just the same
# as if you called 'fit' directly on an OLS estimator instance.

# A benefit of using pipeline is.. 
# as it provides a wrapper that makes it easier to wrap up all your data processing in one 
# 'interface' - it's less tempting to just run the SimpleImputer once on the whole dataset 
# and then do train/test splits etc. 
# The cross_validate function and GridSearchCV class then contain the 
# logic to do the required splits for cross-validation etc - and pass each split into the pipeline.
# As for the imputation on the test data - that happens implicitly as when predict is 
# called on the pipeline for the test data, it will be run through the imputation step then.

pipe = Pipeline([
    ('imputer', SimpleImputer(missing_values=np.nan, strategy='median')),
    ('standardise', StandardScaler()),
    ('estimator', Lasso())
])

# Setup the GridSearch
# This time compare scores for both R-squared and MSE
# NOTE: We actually use negative mean squared error, as scikit-learn always tries to maximise the score 
# NOTE: We're actually going to use two types of scores: R-sq and negative mean squared error 

# later on in the code, when we do LOO, as will use -MSE as our 'primary' scoring method, 
# so the results obtained are comparable with results below

# note, here, we begin with 3-fold inner and 3-fold outer CV
# STUDENTS: If you wanted to change to 5-fold outer and 2-fold inner - what parts of the code would you change?



# Note 'scoring' below shows two metrics (enabling us to present the graphs of both R2 and MSE)
# but GridSearchCV still needs to have a scoring metric on which to calculate the 'best' parameters found

# A note on what GridSearchCV is doing 'internally': it is running through each 'grid point' (combination of parameters - 
# in this case just lambda/alpha), then fitting (actually running the whole pipeline) the training data, then predicting the 
# test data based on this fit, and calculating whatever scoring metric is specified based on this. 
# In this case because we specified both NMSE and R2 it will calculate both of these scores at each grid point. 
# So we can go back and plot each alpha vs either MSE or R2. 
# At the end of the GridSearchCV the 'best' estimator parameters will be chosen based only on (N)MSE though.


scoring = ['r2', 'neg_mean_squared_error']

grid_search_cv = GridSearchCV(estimator=pipe, param_grid=grid, cv=3, return_train_score=True, scoring=scoring, 
                              refit='neg_mean_squared_error')



# STUDENTS: to change to 2-fold inner....
# grid_search_cv = GridSearchCV(estimator=pipe, param_grid=grid, cv=2, return_train_score=True, scoring=scoring, 
#                               refit='neg_mean_squared_error')

# %%
# Nested CV
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_validate 

cv_result_cv = cross_validate(estimator=grid_search_cv, X=X, y=y, cv=3, return_train_score=True, return_estimator=True,
                           scoring=scoring)

# What results "show up in cv_result_cv"? 
# grid_search_cv is the initialised GridSearchCV object which we then pass into  e.g. `cross_validate`. 
# It has a range of methods and attributes, see the documentation
# (https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)

# On a 'fit' GridSearchCV object (ie not this one at this point in the code) you can access attributes such as
# - `best_estimator_`
# - `best_score_`
# - `best_params_`
# but exactly what's accessible depends on the state of the object

# STUDENTS: to change to 5-fold outer....
# cv_result_cv = cross_validate(estimator=grid_search_cv, X=X, y=y, cv=5, return_train_score=True, return_estimator=True,
#                            scoring=scoring)

# %%
# R^2
# Note: these are the average scores across the 3 outer folds..using the 'best' lambda

# the keys returned in cv_results_cv are:
# - fit_time
# - score_time
# - estimator
# - test_r2
# - train_r2
# - test_neg_mean_squared_error
# - train_neg_mean_squared_error
# Most of these are arrays with one value from each CV fold (3 in this case)
# Note that these are configurable/change depending on usage (e.g. estimator is included because we asked for it, 
# same for train score. 
# Obviously the score names changes depending on which scores we've asked for.)
# These aren't 'by default' the results from the 'best' CVs - that behaviour is provided by the GridSearchCV we pass in - 
# `cross_validate` purely runs the CV process and collates the results.

test_score = cv_result_cv['test_r2']
train_score = cv_result_cv['train_r2']
plt.bar(x=range(2), 
        height = [np.mean(train_score), np.mean(test_score)], 
        tick_label=['Train', 'Test'], 
        yerr=[np.std(train_score), np.std(test_score)])
plt.ylabel(r'$R^2$')
plt.title('"Outer" cross-validation scores ($R^2$)')
plt.show()

# %%
# MSE
# Note: these are the average scores across the 3 outer folds..using the 'best' lambda

test_score = cv_result_cv['test_neg_mean_squared_error']
train_score = cv_result_cv['train_neg_mean_squared_error']
plt.bar(x=range(2), 
        height = np.multiply(-1, [np.mean(train_score), np.mean(test_score)]), 
        tick_label=['Train', 'Test'], 
        yerr=[np.std(train_score), np.std(test_score)])
plt.ylabel(r'MSE')
plt.title('"Outer" cross-validation scores (MSE)')
plt.show()

# %%
# STUDENTS: in above figures, why do you think the outer train score always show 
# superior performance of the model compared to the outer test score?
# i.e. Train has: higher R-sq and lower MSE...
# Is that what you would expect? Why?
# If Test score is substantially "worse-off" than train score - what does that suggest?
# A: overfitting

# Note: we only show 'one' average score from the three outer scores from the 3 outer folds
# we could show three outer scores but since the purpose of the outer folds
# is to test the 'overall' generalisability of the model, showing one average is fine

# by contrast, below we show you 'three' separate sets of scores from the 3 folds from the outer folds
# because we are interested in showing how each lambda performed in each of the folds
# each point on the line is the average of the 3 inner folds
# each line is for an outer fold

# %%
# Let's look at the 'internal' test scores for each alpha (lambda) (R^2)

fig, ax = plt.subplots()
ax.set_xscale(value='log')

for estimator in cv_result_cv['estimator']:
    result = estimator.cv_results_
    err = plt.errorbar(x=result['param_estimator__alpha'].data, y=result['mean_test_r2'], yerr=result['std_test_r2'], label='Test')
    plt.errorbar(x=result['param_estimator__alpha'].data, y=result['mean_train_r2'], yerr=result['std_train_r2'], label='Train', 
                 linestyle='dashed', color=err[0].get_color())
    plt.axvline(x=[estimator.best_params_['estimator__alpha'],], color=err[0].get_color())
plt.xlabel('alpha/lambda')
plt.ylabel(r'$R^2$')
plt.title('"Inner" test vs train scores ($R^2$)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Students: why are there 6 lines in the above figure?
# first: are these scores being generated on the 'inner' or 'outer' folds of data
# A: three outer folds - so each colour represents the GridSearchCV 
# run in one of the 3 'outer' folds

# but hold on - didn't we also do 3 inner folds (for each separate outer fold), what happened to them? 
# A: indeed, we did 3-fold "inner" CV and for each inner fold split of train data, we did hyperparameter tuning. 
# But above, for each outer split, we then look at the 'average/stdev' of the (3) 'inner' scores 
# at each tested value of alpha/lambda, which are the actual points plotted

# Put another way, each 'train' line is the average of the 'inner' 3-fold 'train' data outcomes at 
# each lambda, and the same for test (average of the innner 3-fold test runs on each 'outer' run) 

# Students: to the right of the vertical lines "the best lambdas" 
# why do you think the R-sq rapidly declines?
# A: underfitting

# Students: why do you think you get divergence in train and test scores for 
# 'small' values of lambda?
# A: overfitting. small values of lambda means little regularisation/penalisation
# thus you're including many features in the model.

# Students: why do you think you get overlap in train and test scores for 
# 'large' values of lambda? 
# A: large values of lambdas mean that you're penalising heavily e.g. 
# in lasso - you're dropping many features. This is leading to "under-fitting"
# which is bad in both train and test cases. Notice how R-sq is very low.

# Students: why do you think there's difference between the orange test, 
# green test and the blue test scores? 
# A: this is just due to the different data sets created by the splitting, 
# and that this is totally expected 
# (in fact you would be surprised if different splits produced identical results)
# However if there were large difference seen then this might suggest 
# something going on with the data
# (e.g. perhaps data ordered in some way and it could be the data were not shuffled)

# %%
# Let's look at the 'internal' test scores for each alpha (lambda) (MSE)

fig, ax = plt.subplots()
ax.set_xscale(value='log')

for estimator in cv_result_cv['estimator']:
    result = estimator.cv_results_
    err = plt.errorbar(x=result['param_estimator__alpha'].data, y=np.multiply(-1, result['mean_test_neg_mean_squared_error']), 
                       yerr=result['std_test_neg_mean_squared_error'], label='Test')
    plt.errorbar(x=result['param_estimator__alpha'].data, y=np.multiply(-1, result['mean_train_neg_mean_squared_error']), 
                 yerr=result['std_train_neg_mean_squared_error'], label='Train', linestyle='dashed', color=err[0].get_color())
    plt.axvline(x=[estimator.best_params_['estimator__alpha'],], color=err[0].get_color())
plt.xlabel('alpha/lambda')
plt.ylabel(r'MSE')
plt.title('"Inner" test vs train scores (MSE)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ```
# # Now repeat, but rather than 3-fold CV, use leave-one-out
# # NOTE: The following has been done offline, due to prolonged running time
# # Lasso
# from sklearn.model_selection import LeaveOneOut
#
# grid = {
#     'estimator__alpha': np.logspace(-3, -1, 100)
# }
#
# pipe = Pipeline([
#     ('imputer', SimpleImputer(missing_values=np.nan, strategy='median')),
#     ('standardise', StandardScaler()),
#     ('estimator', Lasso())
# ])
#
# # Setup the GridSearch
# # This time compare scores for both R-squared and MSE
# # NOTE: We actually use negative mean squared error, and scikit-learn always tries to maximise the score
# scoring = ['neg_mean_squared_error',]
#
# grid_search_cv = GridSearchCV(estimator=pipe, param_grid=grid, cv=LeaveOneOut(), return_train_score=True, scoring=scoring,
#                               refit='neg_mean_squared_error')
#
# # Nested CV
# import matplotlib.pyplot as plt
# from sklearn.model_selection import cross_validate
#
# cv_result_loo = cross_validate(estimator=grid_search_cv, X=X, y=y, cv=3, return_train_score=True, return_estimator=True,
#                            scoring=scoring)
# ```

# %%
# Note, now we are doing 3-fold outer CV; and LOO for the inner folds

# see how cv_result_loo = cross_validate(estimator=grid_search_cv, X=X, y=y, cv=3, 
        # return_train_score=True, return_estimator=True,  scoring=scoring)..... has cv=3
# but in grid_search_cv = GridSearchCV(estimator=pipe, param_grid=grid, cv=LeaveOneOut(), 
    # return_train_score=True, scoring=scoring, refit='neg_mean_squared_error')..... cv=LeaveOneOut

# note in theory you could run LOO at both 'levels', but this would take an 
# unreasonable amount of time. 
# if you were running on 
# real data you would want to run the LOO within the GridSearch, and use the outer CV just to get an idea 
# of the generalisability of the model

# %% [markdown]
# ```
# # MSE
# test_score = cv_result_loo['test_neg_mean_squared_error']
# train_score = cv_result_loo['train_neg_mean_squared_error']
# plt.bar(x=range(2),
#         height = np.multiply(-1, [np.mean(train_score), np.mean(test_score)]),
#         tick_label=['Train', 'Test'],
#         yerr=[np.std(train_score), np.std(test_score)])
# plt.ylabel(r'MSE')
# plt.title('"Outer" cross-validation scores (MSE)')
# plt.show()
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```
# # Let's look at the 'internal' test scores for each alpha (lambda) (MSE)
#
# fig, ax = plt.subplots()
# ax.set_xscale(value='log')
#
# for estimator in cv_result_loo['estimator']:
#     result = estimator.cv_results_
#     err = plt.errorbar(x=result['param_estimator__alpha'].data, y=np.multiply(-1, result['mean_test_neg_mean_squared_error']),
#                        yerr=result['std_test_neg_mean_squared_error'], label='Test')
#     plt.errorbar(x=result['param_estimator__alpha'].data, y=np.multiply(-1, result['mean_train_neg_mean_squared_error']),
#                  yerr=result['std_train_neg_mean_squared_error'], label='Train', linestyle='dashed', color=err[0].get_color())
#     plt.axvline(x=[estimator.best_params_['estimator__alpha'],], color=err[0].get_color())
# plt.xlabel('alpha/lambda')
# plt.ylabel(r'MSE')
# plt.title('"Inner" test vs train scores (MSE)')
# plt.legend()
# plt.tight_layout()
# plt.show()
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```
#
# # Remember, because the 'outer' CV is 3-fold there are effectively 3 GridSearchCVs run, so when you look at the mean test/train scores for the GridSearchCVs ('inner' scores) you get 3 datasets..
#
# # the difference however, is that within each outer fold, you are now running LOO CV
# # this means that if you have 20,000 observations in your data, you will make 20,000 splits of the data
# # and for each lambda (or associated model), you will be averaging across 20,000 Inner train/test scores
# # i.e. each point along the graph is NO longer averaging across '3 splits' (from 3-fold Inner CV);
# # it is now averaging over 20,000 splits
#
#
# # Students: in previous exercise (3-fold outer; 3-fold inner),
# # we saw the green, blue and orange test lines showed more apparent difference than the graph above
# # but in above figure: they "look" more similar because the error bars are quite a bit larger with the LOO,
# # which is resulting in this graph scaling quite differently to the previous one
#
# ```

# %% [markdown]
# ```
# # Students: please note below, we will switch between 3-fold inner and LOO Inner CV
# # in both cases, we still use 3-fold outer
#
# # 3-fold Inner CV
# # note: only three splits
#
# [x for x in cv_result_cv['estimator'][0].cv_results_.keys() if (('_test_neg_mean_squared_error' in x) and ('split' in x))]
#
# # NOTE: For those of you who haven't seen this form before, this is a python "list comprehension"
# # In essence, what this is doing is taking every 'key' from the first GridSearchCV cv_results, and filtering those that contain the text '_test_neg_mean_squared_error' and 'split'
# ```

# %% [markdown]
# ```
# ['split0_test_neg_mean_squared_error',
#  'split1_test_neg_mean_squared_error',
#  'split2_test_neg_mean_squared_error']
#  ```

# %% [markdown]
# ```
# # Now LOO CV inner
# # Note: there are as many splits as there are number of observations in the communities dataset
#
# [x for x in cv_result_loo['estimator'][0].cv_results_.keys() if (('_test_neg_mean_squared_error' in x) and ('split' in x))]
# ```

# %% [markdown]
# ```
# ['split0_test_neg_mean_squared_error',
#  'split1_test_neg_mean_squared_error',
#  'split2_test_neg_mean_squared_error',
#  'split3_test_neg_mean_squared_error',
#  'split4_test_neg_mean_squared_error',
#  'split5_test_neg_mean_squared_error',
#  'split6_test_neg_mean_squared_error',
#  'split7_test_neg_mean_squared_error',
#  'split8_test_neg_mean_squared_error',
#  'split9_test_neg_mean_squared_error',
#  'split10_test_neg_mean_squared_error',
#  'split11_test_neg_mean_squared_error',
#  'split12_test_neg_mean_squared_error',
#  'split13_test_neg_mean_squared_error',
#  'split14_test_neg_mean_squared_error',
#  'split15_test_neg_mean_squared_error',
#  'split16_test_neg_mean_squared_error',
#  'split17_test_neg_mean_squared_error',
#  'split18_test_neg_mean_squared_error',
#  'split19_test_neg_mean_squared_error',
#  'split20_test_neg_mean_squared_error',
#  'split21_test_neg_mean_squared_error',
#  'split22_test_neg_mean_squared_error',
#  'split23_test_neg_mean_squared_error',
#  'split24_test_neg_mean_squared_error',
# ...
#  'split996_test_neg_mean_squared_error',
#  'split997_test_neg_mean_squared_error',
#  'split998_test_neg_mean_squared_error',
#  'split999_test_neg_mean_squared_error',
#  ...]
#  ```

# %% [markdown]
# ```
#
# # Now back to 3-fold Inner CV...
# # Previously, we always saw the 'average' across 3 inner folds for each point along the graph
# # and we showed the three average scores across the 3 outer folds (thus three lines)
#
# # But below, we show the results from only a single 'outer' fold, and then break that down further
#
# # i.e. we will look at the scores for each inner fold separately: remember there's 3 inner folds
# # and only for '1' outer fold this time
# # thus we see three lines but please note this is different to above (now 3 lines for each inner fold)
#
# test_splits_cv = [x for x in cv_result_cv['estimator'][0].cv_results_.keys() if (('_test_neg_mean_squared_error' in x) and ('split' in x))]
# # Let's look at the 'internal' test scores for each alpha (lambda) (MSE)
#
# fig, ax = plt.subplots()
# ax.set_xscale(value='log')
#
# estimator = cv_result_cv['estimator'][0]
# result = estimator.cv_results_
# for split in test_splits_cv:
#     plt.plot(result['param_estimator__alpha'].data, np.multiply(-1, result[split]))
# plt.axvline(x=[estimator.best_params_['estimator__alpha'],])
# plt.xlabel('alpha/lambda')
# plt.ylabel(r'MSE')
# plt.title('"Inner" test train scores (MSE)')
# plt.tight_layout()
# plt.show()
#
# # students: what part of code changed to show the scores for inner folds separately?
# # A: rather than looking at the `cv_results_` result keyed on `mean_test_neg_mean_squared_error` we're now looking at the keys for each split (e.g. `split..._test_neg_mean_squared_error`)
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```
# # Now back to LOO inner CV...
# # note below, we see many, many lines because there are many splits in LOO (as many as the number of observations)
# # again, we are only seeing the score for '1' outer split
#
# test_splits_cv = [x for x in cv_result_loo['estimator'][0].cv_results_.keys() if (('_test_neg_mean_squared_error' in x) and ('split' in x))]
# # Let's look at the 'internal' test scores for each alpha (lambda) (MSE)
#
# fig, ax = plt.subplots()
# ax.set_xscale(value='log')
#
# estimator = cv_result_loo['estimator'][0]
# result = estimator.cv_results_
# for split in test_splits_cv:
#     plt.plot(result['param_estimator__alpha'].data, np.multiply(-1, result[split]))
# plt.axvline(x=[estimator.best_params_['estimator__alpha'],])
# plt.xlabel('alpha/lambda')
# plt.ylabel(r'MSE')
# plt.title('"Inner" test train scores (MSE)')
# plt.tight_layout()
# plt.show()
# ```

# %%
# students: draw out the nested CV process and try to identify at which 'point' (inner or outer) on each of the graphs 
# do these figures come from 

# students: in graph below why is there this outlier green line?
#A: 'Suggested' answer is this may reflect an outlier in the data itself, 
# which is effectively inflating the error see when the LOO 
# procedure treats this as the 'test' data 

#Students: which portion inner or outer are these scores being generated on?
#A: Inner

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# So what are some of the reasons for/against using LOO as opposed to k-fold CV?
# LOO allows each data point 'equal weighting' in acting as the test data
# LOO is deterministic - there is no randomness  as in selection of 
# k-fold test/training sets
# LOO can take a considerable amount of processing time, especially with large data sets or costly models
